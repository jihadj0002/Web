# %%
import requests
from bs4 import BeautifulSoup
r= requests.get('https://portal.aiub.edu/')
#print(r.status_code)
#print(r.text)
print(r)

soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <noscript>
#    <meta content="0; url=/jsdisable.html" http-equiv="refresh"/>
#   </noscript>
#   <title>
#    Index
#   </title>
#   <link href="/Content/base?v=HDs2NgzSdAl1t6lJ-Kpsluh0IYvV_ojkkmR6EV-1vUg1" rel="stylesheet"/>
#   <style type="text/css">
#    .field-validation-error {
#             color: red;
#         }
#   </style>
#   <link href="/Content/dist/drunkenparrot/css/drunken-parrot.css" rel="stylesheet"/>
#   <style>
#    body {
#          margin: 0;
#          padding: 0;
#          height: 100%;
#          background-color: #efefef;
#      }
#   </style>
#  </head>
#  <body>
#   <div>
#    <div>
#     <span id="loginPath" style="display: none">
#      https://portal.aiub.edu/
#     </span>
#     <div class="text-center">
#      <div class="login-form">
#       <div>
#        <a href="http://www.aiub.edu">
# ...
